# %% [markdown]
# <a href="https://colab.research.google.com/github/anjineyulutv/Steerable-Dataset-Generator/blob/main/Sarvam_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
/content/drive/MyDrive/ocr_vlm_solution_full.zip

# %%
# prompt: unzip a folder from drive,it is already mounted

# !unzip /content/drive/MyDrive/ocr_vlm_solution_full.zip
# Out:
# Archive:  /content/drive/MyDrive/ocr_vlm_solution_full.zip
#   inflating: home/ubuntu/advanced_image_processing.py
#   inflating: home/ubuntu/baseline_inference.py
#   inflating: home/ubuntu/dataset_preparation.py
#   inflating: home/ubuntu/fine_tune_vlm.py
#   inflating: home/ubuntu/inspect_dataset.py
#   inflating: home/ubuntu/prepare_dataset_labels.py
#   inflating: home/ubuntu/sanskrit_ocr_preprocess.py
#   inflating: home/ubuntu/setup_together_ai.py
#   inflating: home/ubuntu/text_organization.py
#   inflating: home/ubuntu/vlm_post_ocr.py
#    creating: home/ubuntu/sanskrit_dataset/
#    creating: home/ubuntu/sanskrit_dataset/images/
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0001.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0002.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0003.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0004.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0005.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0006.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0007.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0008.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0009.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0010.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0011.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0012.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0013.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0016.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0017.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0020.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0021.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0022.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0024.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0025.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0026.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0027.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0028.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0030.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0031.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0032.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0033.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0034.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0035.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0036.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0037.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0038.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0039.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0040.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0041.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0045.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0058.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0015.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0018.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0019.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0023.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0029.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0042.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0043.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0044.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0046.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0047.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0048.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0049.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0050.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0051.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0052.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0053.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0054.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0055.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0056.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0057.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0059.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0060.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0061.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0062.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0063.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0064.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0065.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0066.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0067.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0068.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0069.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0070.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0071.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0074.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0075.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0076.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0077.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0078.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0079.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0080.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0082.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0085.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0086.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0087.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0088.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0089.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0090.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0091.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0092.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0093.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0094.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0095.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0096.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0097.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0098.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0099.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0100.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0014.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0072.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0073.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0081.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0083.png
#   inflating: home/ubuntu/sanskrit_dataset/images/Swarupsannidhan_0084.png
#    creating: home/ubuntu/sanskrit_dataset/labels/
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0001.txt
#  extracting: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0002.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0003.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0004.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0005.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0006.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0007.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0008.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0009.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0010.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0011.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0012.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0013.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0016.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0017.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0020.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0021.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0022.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0024.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0025.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0026.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0027.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0028.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0030.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0031.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0032.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0033.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0034.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0035.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0036.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0037.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0038.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0039.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0040.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0041.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0045.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0058.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0015.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0018.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0019.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0023.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0029.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0042.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0043.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0044.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0046.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0047.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0048.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0049.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0050.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0051.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0052.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0053.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0054.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0055.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0056.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0057.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0059.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0060.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0061.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0062.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0063.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0064.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0065.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0066.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0067.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0068.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0069.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0070.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0071.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0074.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0075.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0076.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0077.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0078.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0079.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0080.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0082.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0085.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0086.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0087.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0088.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0089.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0090.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0091.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0092.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0093.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0094.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0095.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0096.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0097.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0098.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0099.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0100.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0014.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0072.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0073.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0081.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0083.txt
#   inflating: home/ubuntu/sanskrit_dataset/labels/Swarupsannidhan_0084.txt
#   inflating: home/ubuntu/ocr_vlm_report.md

# %%
pwd
# Out:
# '/content'

# %%
ll
# Out:
# total 12
# drwx------ 6 root 4096 Jun 16 09:31 drive/
# drwxr-xr-x 3 root 4096 Jun 16 09:31 home/
# drwxr-xr-x 1 root 4096 Jun 12 13:36 sample_data/

# %%
pwd
# Out:
# '/content'

# %%
cd home/ubuntu
# Out:
# /content/home/ubuntu

# %%
ll
# Out:
# total 56
# -rw-r--r-- 1 root 3086 Jun 15 05:06 advanced_image_processing.py
# -rw-r--r-- 1 root 1496 Jun 15 06:45 baseline_inference.py
# -rw-r--r-- 1 root 3478 Jun 15 05:03 dataset_preparation.py
# -rw-r--r-- 1 root 3357 Jun 15 12:09 fine_tune_vlm.py
# -rw-r--r-- 1 root  411 Jun 15 06:32 inspect_dataset.py
# -rw-r--r-- 1 root 8263 Jun 15 12:13 ocr_vlm_report.md
# -rw-r--r-- 1 root 1602 Jun 15 11:43 prepare_dataset_labels.py
# drwxrwxr-x 4 root 4096 Jun 15 11:44 sanskrit_dataset/
# -rw-r--r-- 1 root 2603 Jun 15 05:56 sanskrit_ocr_preprocess.py
# -rw-r--r-- 1 root  881 Jun 15 11:30 setup_together_ai.py
# -rw-r--r-- 1 root 1775 Jun 15 06:04 text_organization.py
# -rw-r--r-- 1 root 2929 Jun 15 11:35 vlm_post_ocr.py

# %%
# !pip install together
# !python fine_tune_vlm.py
# Out:
# Requirement already satisfied: together in /usr/local/lib/python3.11/dist-packages (1.5.14)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.3 in /usr/local/lib/python3.11/dist-packages (from together) (3.11.15)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from together) (8.1.8)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from together) (0.2.2)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /usr/local/lib/python3.11/dist-packages (from together) (3.18.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from together) (2.0.2)
# Requirement already satisfied: pillow<12.0.0,>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from together) (11.2.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.3 in /usr/local/lib/python3.11/dist-packages (from together) (2.11.5)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from together) (2.32.3)
# Requirement already satisfied: rich<15.0.0,>=13.8.1 in /usr/local/lib/python3.11/dist-packages (from together) (13.9.4)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from together) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from together) (4.67.1)
# Requirement already satisfied: typer<0.16,>=0.9 in /usr/local/lib/python3.11/dist-packages (from together) (0.15.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.20.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->together) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->together) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->together) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->together) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<15.0.0,>=13.8.1->together) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<15.0.0,>=13.8.1->together) (2.19.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<0.16,>=0.9->together) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.8.1->together) (0.1.2)
# 2025-06-16 10:21:46.642552: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750069306.670393   17894 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750069306.678113   17894 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-16 10:21:46.703416: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🚀 Starting OCR Fine-tuning with Together.ai
# ==================================================
# Processing images:  38% 38/100 [00:10<00:14,  4.19it/s]WARNING:__main__:Empty label for Swarupsannidhan_0002.png
# Processing images: 100% 100/100 [00:26<00:00,  3.81it/s]
# ERROR:__main__:❌ Failed to upload file ocr_dataset_train.jsonl: File validation failed: Invalid format on line 1 in the column content for turn `{'role': 'user', 'content': [{'type': 'text', 'text': 'Please extract all text from this image:'}, {'type': 'image_url', 'image_url': {'url': 'data:image/jpeg;base64,...'}}]}` of the input file. Expected string. Found <class 'list'>
# ERROR:__main__:❌ Fine-tuning failed: File validation failed: Invalid format on line 1 in the column content for turn `{'role': 'user', 'content': [{'type': 'text', 'text': 'Please extract all text from this image:'}, {'type': 'image_url', 'image_url': {'url': 'data:image/jpeg;base64,...'}}]}` of the input file. Expected string. Found <class 'list'>
# Traceback (most recent call last):
#   File "/content/home/ubuntu/fine_tune_vlm.py", line 717, in main
#     train_file_id = finetuner.validate_and_upload_file(train_file)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/home/ubuntu/fine_tune_vlm.py", line 255, in validate_and_upload_file
#     raise ValueError(f"File validation failed: {report.get('message', 'Unknown error')}")
# ValueError: File validation failed: Invalid format on line 1 in the column content for turn `{'role': 'user', 'content': [{'type': 'text', 'text': 'Please extract all text from this image:'}, {'type': 'image_url', 'image_url': {'url': 'data:image/jpeg;base64,...'}}]}` of the input file. Expected string. Found <class 'list'>

# %% [markdown]
# # Welcome to Colab!
#
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning
#
# <div>
#
# These are a few of the notebooks related to Machine Learning, including Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Getting Started with cuML's accelerator mode](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cuml_sklearn_colab_demo.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TPUs in Colab](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.
